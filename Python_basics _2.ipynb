# %% [markdown]
# # 準備回 Python 基礎

# %% [markdown]
# ## 0-1. ライブラリの読み込み

# %%
# OS（オペレーティングシステム）に依存した機能を使うための標準ライブラリ
import os
#os.getcwd() # 現在のディレクトリを返す

# %%
from PIL import Image # 画像の読み書きをするライブラリー pillow

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# jupyter内に描画

# %% [markdown]
# ## 0-2. Pandas: データフレームの取り扱い

# %%
# CSVファイルの読み込み
df = pd.read_csv("./data/pulsar_stars.csv") # df = dataframe の略

# %%
# 最初の５行を表示
df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
# pandas の dataframe の行と列の表示
df.shape
# Out:
# (17898, 9)

# %%
# dataframe をCSVファイルとして保存
df.to_csv("dataframe.csv",index=False)

# %% [markdown]
# ## 0-3. Numpy: データ配列の取り扱い

# %%
# 画像ファイルの読み込み
img_org = Image.open("./data/a48009.jpg")

# 「./data/ファイル名」、「/data/ファイル名」、「data/ファイル名」のどれも有効
# 文字列の記述は、"文字列" でも '文字鉄' でもよい。(デフォルトは「''」だが「""」の方がタイプしやすい)

# %%
img_org
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1E34A5B4208>

# %%
# 画像データの表示
#plt.imshow(img_org)
#plt.show()

# %%
# 画像データを Numpy 配列に変換
img = np.array(img_org)

# %%
print("データ型：",img.dtype)  # データ型
print("次元数：",img.ndim)  # 次元数
print("サイズ",img.shape)  # サイズ（高さ x 幅 x 色数）
# Out:
# データ型： uint8
# 次元数： 3
# サイズ (256, 256, 3)

# %%
# Numpy 配列(arrey) image の表示 -> (256, 256, 3) の３次元配列
img
# Out:
# array([[[ 48,  63, 156],
#         [ 48,  63, 156],
#         [ 48,  63, 156],
#         ...,
#         [ 52,  69, 201],
#         [ 53,  70, 200],
#         [ 54,  71, 201]],
#
#        [[ 49,  64, 157],
#         [ 49,  64, 157],
#         [ 49,  64, 157],
#         ...,
#         [ 52,  69, 201],
#         [ 53,  70, 200],
#         [ 54,  71, 201]],
#
#        [[ 49,  64, 157],
#         [ 49,  64, 157],
#         [ 49,  64, 157],
#         ...,
#         [ 53,  70, 202],
#         [ 53,  70, 200],
#         [ 53,  70, 200]],
#
#        ...,
#
#        [[143, 122, 137],
#         [144, 123, 138],
#         [143, 122, 137],
#         ...,
#         [118,  94, 110],
#         [147, 123, 139],
#         [ 93,  70,  88]],
#
#        [[114,  93, 110],
#         [117,  96, 111],
#         [117,  97, 109],
#         ...,
#         [120,  98, 111],
#         [165, 142, 158],
#         [ 87,  64,  82]],
#
#        [[127, 106, 123],
#         [129, 109, 121],
#         [127, 107, 118],
#         ...,
#         [124, 102, 115],
#         [186, 163, 179],
#         [102,  79,  97]]], dtype=uint8)

# %%
# Numpy配列を画像として表示
plt.imshow(img)
plt.show()
# Out:
# findfont: Font family ['IPAexGothic'] not found. Falling back to DejaVu Sans.

# %%
# 画像ファイルとして保存
np.save("img_array", img)

# %%
# Numpy 配列ファイルの読み込み
np.load(file="img_array.npy")
# Out:
# array([[[ 48,  63, 156],
#         [ 48,  63, 156],
#         [ 48,  63, 156],
#         ...,
#         [ 52,  69, 201],
#         [ 53,  70, 200],
#         [ 54,  71, 201]],
#
#        [[ 49,  64, 157],
#         [ 49,  64, 157],
#         [ 49,  64, 157],
#         ...,
#         [ 52,  69, 201],
#         [ 53,  70, 200],
#         [ 54,  71, 201]],
#
#        [[ 49,  64, 157],
#         [ 49,  64, 157],
#         [ 49,  64, 157],
#         ...,
#         [ 53,  70, 202],
#         [ 53,  70, 200],
#         [ 53,  70, 200]],
#
#        ...,
#
#        [[143, 122, 137],
#         [144, 123, 138],
#         [143, 122, 137],
#         ...,
#         [118,  94, 110],
#         [147, 123, 139],
#         [ 93,  70,  88]],
#
#        [[114,  93, 110],
#         [117,  96, 111],
#         [117,  97, 109],
#         ...,
#         [120,  98, 111],
#         [165, 142, 158],
#         [ 87,  64,  82]],
#
#        [[127, 106, 123],
#         [129, 109, 121],
#         [127, 107, 118],
#         ...,
#         [124, 102, 115],
#         [186, 163, 179],
#         [102,  79,  97]]], dtype=uint8)

# %% [markdown]
# # 0-4. Matplotlib: グラフ描画

# %%
# 乱数を生成
x = np.random.rand(40)
y = np.random.rand(40)
 
# 散布図を描画
plt.scatter(x, y)

# %%
# Numpy と Matplotlib を用いた三角関数を描画

def Trigonometric_Plot(i):
    x = np.linspace(-i*np.pi, i*np.pi)
    plt.plot(x, np.cos(x), color='r', ls='-', label='cos')
    plt.plot(x, np.sin(x), color='b', marker='p', ls=':', label='sin')
    plt.plot(x, np.tan(x), color='c', marker='s', ls='-', label='tan')

    plt.xlim(-np.pi, np.pi)
    plt.ylim(-1.5, 1.5)

    plt.axhline(0, ls='-', c='b', lw=0.5)
    plt.axvline(0, ls='-', c='b', lw=0.5)

    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Trigonometric functions')

    plt.show()

# %%
Trigonometric_Plot(3)

# %% [markdown]
# ### グラフプロットコードをまとめた Web-site

# %% [markdown]
# #### https://www.data-to-viz.com

# %%
# 散布図

# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt
 
# Basic correlogram
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## 0-5. クラスと関数

# %%
# historyクラスを定期
class history:
    def __init__(acc, val_acc, loss, val_loss):
        self.acc = acc
        self.val_acc = val_acc
        self.loss = loss
        self.val_loss = val_loss

# 関数 Learning_Process_Plot() を定義 --> 引数は historyクラス
def Learning_Process_Plot(history):
    acc = history.acc
    val_acc = history.val_acc
    loss = history.loss
    val_loss = history.val_loss

    epochs = range(len(acc))

    plt.plot(epochs, acc, label='Training acc', ls="-", marker="o")
    plt.plot(epochs, val_acc, label='Validation acc', ls="-", marker="x")
    plt.title('Training and validation accuracy')
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(loc="best")
    plt.savefig('acc_graph.png') # acc, val_acc グラフ保存

    plt.figure()

    plt.plot(epochs, loss, label='Training loss', ls="-", marker="o")
    plt.plot(epochs, val_loss, label='Validation loss', ls="-", marker="x")
    plt.title('Training and validation loss')
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.legend(loc="best")
    plt.savefig('loss_graph.png') # loss, val_loss グラフ保存

    plt.show()

# %%
# historyクラスにメンバーを入力
his = history
his.acc = [0.50376884, 0.75753769, 0.85050251, 0.91708543, 0.93592965]
his.val_acc = [0.665, 0.875, 0.86, 0.955, 0.975]
his.loss = [1.0869408207922127, 0.612384136298194, 0.4129973124319585, 0.2651988666261261, 0.20133653537711904]
his.val_loss = [0.7168122148513794, 0.4103385591506958, 0.3806729394197464, 0.15852605164051056, 0.11399855181574821]

# 関数Learning_Process_Plot()
Learning_Process_Plot(his)

# %% [markdown]
# ## 0-6. 条件文

# %%
# If elif else 文

def IF_Sample(i):
    if i == 1:
        print("i = 1")
    elif i == 2:
        print("i = 2")
    else:
        print("i は 1 でも 2 でもない ")

# %%
IF_Sample(5)
# Out:
# i は 1 でも 2 でもない

# %% [markdown]
# ## 0-7. ループ

# %%
# for ループ --> range() の範囲内で繰り返す

def f(i):
    f =  i * i
    return f

def For_Loop(i):
    for i in range(i+1):
        j = f(i)
        print(j)
    print("END")

# %%
For_Loop(7)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# END

# %%
# while ループ --> 条件に合う間は繰り返す

def While_Loop(i):
    while 0 <= i:
         j = f(i)
         print(j)
         i -= 1
    else:
         print("END")

# %%
While_Loop(7)
# Out:
# 49
# 36
# 25
# 16
# 9
# 4
# 1
# 0
# END
